# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/df_ab.csv')
df
# Out:
#      user id      group  session count  pages per session  time on site total  \
# 0        154    control            7.0           5.047098           10.369471
# 1        481  treatment           13.0           4.472695           45.864260
# 2        391  treatment            8.0           6.819330           35.129400
# 3        436  treatment           21.0           5.029693           74.320743
# 4        320    control           12.0           4.040592           32.734682
# ..       ...        ...            ...                ...                 ...
# 495      203    control           13.0           3.740958           29.904765
# 496      336    control            5.0           4.309821           13.786639
# 497      136    control           12.0           3.426300           31.691408
# 498      359  treatment           14.0           3.850722           33.100314
# 499      225    control           12.0           3.809318           30.539211
#
# ...

# %%
plt.figure(figsize=(10, 6))  # размер полотна — широкий, чтобы было наглядно
plt.hist(df['total spent'], bins=30, color='skyblue', edgecolor='black')
plt.title('Распределение общей выручки с пользователя', fontsize=14)
plt.xlabel('total_spent, руб.', fontsize=12)
plt.ylabel('Количество пользователей', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
